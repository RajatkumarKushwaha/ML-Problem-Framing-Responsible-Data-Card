# %% [markdown]
# # ML Problem Framing & Responsible Data Card

# %%
# import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('customer-churned-training.csv')

# %%
df.head()
# Out:
#   customer_id  tenure_months  support_tickets  monthly_spend_inr  \
# 0        C001              2                4                499
# 1        C002             18                1               1299
# 2        C003              6                3                799
# 3        C004             30                0               1499
# 4        C005             11                2                999
#
#    last_login_days plan_type  churned
# 0               21     Basic        1
# 1                2       Pro        0
# 2               14     Basic        1
# 3                1       Pro        0
# 4                5  Standard        0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        12 non-null     str
#  1   tenure_months      12 non-null     int64
#  2   support_tickets    12 non-null     int64
#  3   monthly_spend_inr  12 non-null     int64
#  4   last_login_days    12 non-null     int64
#  5   plan_type          12 non-null     str
#  6   churned            12 non-null     int64
# dtypes: int64(5), str(2)
# memory usage: 918.0 bytes

# %%
df.columns.tolist()
# Out:
# ['customer_id',
#  'tenure_months',
#  'support_tickets',
#  'monthly_spend_inr',
#  'last_login_days',
#  'plan_type',
#  'churned']

# %%
# Check for Missing/Null Values
df.isnull().sum()
# Out:
# customer_id          0
# tenure_months        0
# support_tickets      0
# monthly_spend_inr    0
# last_login_days      0
# plan_type            0
# churned              0
# dtype: int64

# %%
# Check count of duplicate entries
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check counts and percentage of target variable
df['churned'].value_counts()
df['churned'].value_counts(normalize=True) * 100
# Out:
# churned
# 0    58.333333
# 1    41.666667
# Name: proportion, dtype: float64
